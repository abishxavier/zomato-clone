# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://root:root@localhost:3307/zomato

# %%
# %%sql
# create database zomato;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# (mysql.connector.errors.DatabaseError) 1007 (HY000): Can't create database 'zomato'; database exists
# [SQL: create database zomato;]
# (Background on this error at: https://sqlalche.me/e/20/4xp6)

# %%
# %%sql
# USE zomato;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS orders (
#     order_id INT AUTO_INCREMENT PRIMARY KEY,
#     user_id INT,
#     item_id INT,
#     quantity INT NOT NULL,
#     delivery_address VARCHAR(255) NOT NULL,
#     order_date TIMESTAMP DEFAULT CURRENT_TIMESTAMP
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 0 rows affected.
# []

# %%
# %%sql #Insert sample data into orders table
# INSERT INTO orders (user_id, item_id, quantity, delivery_address) VALUES
# (1, 1, 2, '123 Main St'),
# (2, 2, 1, '456 Oak Rd'),
# (3, 3, 3, '789 Pine Ave');
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 3 rows affected.
# []

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS categories (
#     category_id INT AUTO_INCREMENT PRIMARY KEY,
#     category_name VARCHAR(255) NOT NULL
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 0 rows affected.
# []

# %%
# %%sql #-- Insert sample data into categories table
# INSERT INTO categories (category_name) VALUES
# ('Vegetarian'),
# ('Non-Vegetarian'),
# ('Vegan');
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 3 rows affected.
# []

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS items (
#     item_id INT AUTO_INCREMENT PRIMARY KEY,
#     item_name VARCHAR(255) NOT NULL,
#     price DECIMAL(10, 2) NOT NULL,
#     category_id INT
# );
# Out:
#    mysql+mysqlconnector://root:***@localhost:3307/test
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO items (item_name, price, category_id) VALUES
# ('Biriyani', 150.00, 2),
# ('Paneer', 100.00, 1),
# ('Butter Chicken', 200.00, 2);
# Out:
#    mysql+mysqlconnector://root:***@localhost:3307/test
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 3 rows affected.
# []

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS order_items (
#     order_item_id INT AUTO_INCREMENT PRIMARY KEY,
#     order_id INT,
#     item_id INT,
#     quantity INT NOT NULL,
#     price DECIMAL(10, 2),
#     FOREIGN KEY (item_id) REFERENCES items(item_id)
# );
# Out:
#    mysql+mysqlconnector://root:***@localhost:3307/test
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO order_items (order_id, item_id, quantity, price) VALUES
# (1, 1, 2, 150.00),
# (2, 2, 1, 100.00),
# (3, 3, 3, 200.00);
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# (mysql.connector.errors.IntegrityError) 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`zomato`.`order_items`, CONSTRAINT `order_items_ibfk_1` FOREIGN KEY (`item_id`) REFERENCES `items` (`item_id`))
# [SQL: INSERT INTO order_items (order_id, item_id, quantity, price) VALUES
# (1, 1, 2, 150.00),
# (2, 2, 1, 100.00),
# (3, 3, 3, 200.00);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# %%sql
# INSERT INTO order_items (order_id, item_id, quantity, price)
# VALUES (1, 4, 2, 150.00),
#        (2, 5, 1, 100.00),
#        (3, 6, 3, 200.00);
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 3 rows affected.
# []

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS payments (
#     payment_id INT AUTO_INCREMENT PRIMARY KEY,
#     order_id INT,
#     payment_method VARCHAR(50),
#     payment_status VARCHAR(50),
#     amount DECIMAL(10, 2),
#     paid_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
# );
# Out:
#    mysql+mysqlconnector://root:***@localhost:3307/test
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 0 rows affected.
# []

# %%
# %%sql
# SELECT * FROM items;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 3 rows affected.
# [(4, 'Biriyani', Decimal('150.00'), 2),
#  (5, 'Paneer', Decimal('100.00'), 1),
#  (6, 'Butter Chicken', Decimal('200.00'), 2)]

# %%
# %%sql
# INSERT INTO payments (order_id, payment_method, payment_status, amount) VALUES
# (1, 'Credit Card', 'Paid', 300.00),
# (2, 'Debit Card', 'Paid', 100.00),
# (3, 'GPay', 'Pending', 600.00);
# Out:
#    mysql+mysqlconnector://root:***@localhost:3307/test
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 3 rows affected.
# []

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS customers (
#     user_id INT PRIMARY KEY,
#     first_name VARCHAR(255),
#     last_name VARCHAR(255),
#     phone_number VARCHAR(15),
#     email VARCHAR(255)
# );
# Out:
#    mysql+mysqlconnector://root:***@localhost:3307/test
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO customers (user_id, first_name, last_name, phone_number, email) VALUES
# (1, 'John', 'Doe', '123-456-7890', 'john.doe@example.com'),
# (2, 'Jane', 'Smith', '987-654-3210', 'jane.smith@example.com'),
# (3, 'Alice', 'Johnson', '111-222-3333', 'alice.johnson@example.com'),
# (4, 'Bob', 'Brown', '444-555-6666', 'bob.brown@example.com'),
# (5, 'Gowtham', 'Kumar', '777-888-9999', 'gowtham.kumar@example.com');
# Out:
#    mysql+mysqlconnector://root:***@localhost:3307/test
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 5 rows affected.
# []

# %%
# %%sql
# select * from orders;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 11 rows affected.
# [(1, 1, 1, 2, '123 Main St', datetime.datetime(2026, 4, 14, 15, 57, 24)),
#  (2, 2, 2, 1, '456 Oak Rd', datetime.datetime(2026, 4, 14, 15, 57, 24)),
#  (3, 3, 3, 3, '789 Pine Ave', datetime.datetime(2026, 4, 14, 15, 57, 24)),
#  (4, 1, 1, 2, '123 Main St', datetime.datetime(2026, 4, 14, 16, 16, 21)),
#  (5, 2, 2, 1, '456 Oak Rd', datetime.datetime(2026, 4, 14, 16, 16, 21)),
#  (6, 3, 3, 3, '789 Pine Ave', datetime.datetime(2026, 4, 14, 16, 16, 21)),
#  (7, 1, 4, 1, 'karur', datetime.datetime(2026, 4, 16, 16, 49, 10)),
#  (8, 1, 5, 1, 'karur', datetime.datetime(2026, 4, 16, 16, 49, 10)),
#  (9, 1, 1, 2, '123 Main St', datetime.datetime(2026, 4, 16, 16, 49, 24)),
#  (10, 2, 2, 1, '456 Oak Rd', datetime.datetime(2026, 4, 16, 16, 49, 24)),
#  (11, 3, 3, 3, '789 Pine Ave', datetime.datetime(2026, 4, 16, 16, 49, 24))]

# %%
========== ETL ===================

# %%
# %%sql
# select * from order_items
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 3 rows affected.
# [(8, 1, 4, 2, Decimal('150.00')),
#  (9, 2, 5, 1, Decimal('100.00')),
#  (10, 3, 6, 3, Decimal('200.00'))]

# %%
Total Revenue from All Orders

# %%
# %%sql
# SELECT SUM(oi.price * oi.quantity) AS total_revenue
# FROM order_items oi;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 1 rows affected.
# [(Decimal('1000.00'),)]

# %%
Revenue by Item

# %%
# %%sql
#
# SELECT i.item_name, SUM(oi.price * oi.quantity) AS total_revenue
# FROM order_items oi
# JOIN items i ON oi.item_id = i.item_id
# GROUP BY i.item_name
# ORDER BY total_revenue DESC;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/test
# 3 rows affected.
# [('Butter Chicken', Decimal('600.00')),
#  ('Biriyani', Decimal('300.00')),
#  ('Paneer', Decimal('100.00'))]

# %%
Revenue by Payment Method

# %%
# %%sql
# SELECT p.payment_method, SUM(p.amount) AS total_revenue
# FROM payments p
# JOIN orders o ON p.order_id = o.order_id
# GROUP BY p.payment_method;
# Out:
#    mysql+mysqlconnector://root:***@localhost:3307/test
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 3 rows affected.
# [('Credit Card', Decimal('300.00')),
#  ('Debit Card', Decimal('100.00')),
#  ('GPay', Decimal('600.00'))]

# %%
Total Revenue by Date

# %%
# %%sql
# SELECT DATE(p.paid_at) AS date, SUM(p.amount) AS daily_revenue
# FROM payments p
# GROUP BY DATE(p.paid_at)
# ORDER BY date;
# Out:
#    mysql+mysqlconnector://root:***@localhost:3307/test
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 1 rows affected.
# [(datetime.date(2026, 4, 14), Decimal('1000.00'))]

# %%
Total Orders and Revenue by User

# %%
# %%sql
# drop table if exists users;
# create table users(
#     user_id INT AUTO_INCREMENT PRIMARY KEY,
#     first_name VARCHAR(50),
#     last_name VARCHAR(50),
#     phone_number VARCHAR(20),
#     email VARCHAR(100)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO users(first_name, last_name, phone_number, email)
# VALUES ('John','Doe','4784815181','johndoe@emaple.com'),
# ('Jane', 'smith', '3434313337', 'janesmith@emample.com'),
# ('Alice', 'Johnson', '7444445047', 'alice@emample.com');
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 3 rows affected.
# []

# %%
# %%sql
# SELECT
#     u.first_name,
#     u.last_name,
#     u.phone_number,
#     u.email,
#     COUNT(o.order_id) AS total_orders,
#     SUM(oi.price * oi.quantity) AS total_revenue
# FROM orders o
# JOIN order_items oi ON o.order_id = oi.order_id
# JOIN users u ON o.user_id = u.user_id
# GROUP BY u.user_id
# ORDER BY total_revenue DESC;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 3 rows affected.
# [('Alice', 'Johnson', '7444445047', 'alice@emample.com', 1, Decimal('600.00')),
#  ('John', 'Doe', '4784815181', 'johndoe@emaple.com', 1, Decimal('300.00')),
#  ('Jane', 'smith', '3434313337', 'janesmith@emample.com', 1, Decimal('100.00'))]

# %%
ITEMS ORDERED BY CATEGORY

# %%
# %%sql
# select c.category_name, i.item_name, SUM(oi.quantity) as total_quantity_ordered
# from order_items oi
# JOIN items i on oi.item_id = i.item_id
# JOIN categories c on i.category_id = c.category_id
# GROUP BY c.category_name, i.item_name
# ORDER BY total_quantity_ordered DESC;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 3 rows affected.
# [('Non-Vegetarian', 'Butter Chicken', Decimal('3')),
#  ('Non-Vegetarian', 'Biriyani', Decimal('2')),
#  ('Vegetarian', 'Paneer', Decimal('1'))]

# %%
ORDERS BY PAYMENT STATUS

# %%
# %%sql
# select p.payment_status, COUNT(o.order_id) AS total_ordders
# FROM payments p
# JOIN orders o ON p.order_id = o.order_id
# GROUP BY p.payment_status;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 2 rows affected.
# [('Paid', 2), ('Pending', 1)]

# %%
USERS WITH MOST ORDERS

# %%
# %%sql
# SELECT
#     u.first_name,
#     u.last_name,
#     COUNT(o.order_id) AS total_orders
# FROM users u
# JOIN orders o ON u.user_id = o.user_id
# GROUP BY u.user_id
# ORDER BY total_orders DESC
# LIMIT 5;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 3 rows affected.
# [('John', 'Doe', 5), ('Jane', 'smith', 3), ('Alice', 'Johnson', 3)]

# %%
Revenue by Category

# %%
# %%sql
# SELECT c.category_name, SUM(oi.price * oi.quantity) AS total_revenue
# FROM order_items oi
# JOIN items i ON oi.item_id = i.item_id
# JOIN categories c ON i.category_id = c.category_id
# GROUP BY c.category_name;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 2 rows affected.
# [('Non-Vegetarian', Decimal('900.00')), ('Vegetarian', Decimal('100.00'))]

# %%
Items Purchased in Specific Order

# %%
# %%sql
# SELECT oi.order_id, i.item_name, oi.quantity, oi.price
# FROM order_items oi
# JOIN items i ON oi.item_id = i.item_id
# WHERE oi.order_id = 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 1 rows affected.
# [(1, 'Biriyani', 2, Decimal('150.00'))]

# %%
Customer Details with Orders

# %%
# %%sql
# SELECT
#     c.first_name,
#     c.last_name,
#     c.phone_number,
#     c.email,
#     o.order_id,
#     o.delivery_address,
#     oi.item_id,
#     oi.quantity
# FROM orders o
# JOIN order_items oi ON o.order_id = oi.order_id
# JOIN customers c ON o.user_id = c.user_id;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 3 rows affected.
# [('John', 'Doe', '123-456-7890', 'john.doe@example.com', 1, '123 Main St', 4, 2),
#  ('Jane', 'Smith', '987-654-3210', 'jane.smith@example.com', 2, '456 Oak Rd', 5, 1),
#  ('Alice', 'Johnson', '111-222-3333', 'alice.johnson@example.com', 3, '789 Pine Ave', 6, 3)]

# %%
Revenue by Customer

# %%
# %%sql
# SELECT
#     c.first_name,
#     c.last_name,
#     c.phone_number,
#     c.email,
#     SUM(oi.price * oi.quantity) AS total_revenue
# FROM orders o
# JOIN order_items oi ON o.order_id = oi.order_id
# JOIN customers c ON o.user_id = c.user_id
# GROUP BY c.user_id
# ORDER BY total_revenue DESC;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3307/zomato
# 3 rows affected.
# [('Alice', 'Johnson', '111-222-3333', 'alice.johnson@example.com', Decimal('600.00')),
#  ('John', 'Doe', '123-456-7890', 'john.doe@example.com', Decimal('300.00')),
#  ('Jane', 'Smith', '987-654-3210', 'jane.smith@example.com', Decimal('100.00'))]
